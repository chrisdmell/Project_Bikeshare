# %%
import pandas as pd
import numpy as np
import time
import datetime

chicago = 'chicago.csv'
nyu = 'new_york_city.csv'
washington = 'washington.csv'

def get_city():
    '''Asks the user for a city and returns the filename for that city's bike share data.

    Args:
        none.
    Returns:
        (str) Filename for a city's bikeshare data.
    '''
    city = input('\nHello! Let\'s explore some US bikeshare data!\n'
                 'Would you like to see data for Chicago, New York, or Washington?\n').lower()
    # TODO: handle raw input and complete function
    city_name = ""
    if city.lower() == "chicago":
        city_name = chicago
        return(city_name)
        

    elif city.lower() == "new york":
        city_name = nyu
        return(city_name)
        
        
    elif city == "washington":
        city_name = washington
        return(city_name)       

    else:
        print("Invalid Entry..... Kindly re-enter")
        get_city()
        return(city_name)
    
def get_time_period():
    '''Asks the user for a time period and returns the specified filter.

    Args:
        none.
    Returns: time_period
    '''
    time_period = input('\nWould you like to filter the data by month, day, or none at'
                        ' all? Type "none" for no time filter.\n').lower()

    if time_period.lower() == "month" or time_period.lower() == "day" or time_period.lower() == "none":
        print("Time Period selected :{}".format(time_period))
        return(time_period)

    else:
        print("{} is Invalied entry, Kindly re-enter".format(time_period.title()))
        get_time_period()
        return(time_period)

def get_names(gtp,gc):
    '''
    Filters the data according to user input

    Args:
        gtp = get time period - takes in month, day or nonr
        gc =  get city - takes city file name
        
    Returns: filtered data frame
    '''

    if gtp == "month":

            month = input('\nWhich month? January, February, March, April, May, or June?\n').lower()
            # TODO: handle raw input and complete function
            if month == "january" or month == "february" or month == "march" or month == "april" or month == "may" or month == "june":
                print("Month selected :{}".format(month.title()))
                df = pd. read_csv(gc)
                df['Start Time'] = pd.to_datetime(df['Start Time'])
                df['months'] = df['Start Time'].dt.month
                mapping = {1:'january', 2:'february', 3:'march', 4:'april', 5:'may', 6:'june'}
                df = df.applymap(lambda s: mapping.get(s) if s in mapping else s)
                df = df.loc[df['months'] == month]

                return(df)

            else:
                print("{} is Invalied entry, Kindly re-enter".format(month.title()))
                month = input('\nWhich month? January, February, March, April, May, or June?\n').lower()



    elif gtp == "day":
            month = input('\nWhich day? Sunday, Monday, Tuesday, Wednesday, Thursday, Friday or saturday?\n').lower()

            if month == "sunday" or month == "monday" or month == "tuesday" or month == "wednesday" or month == "thursday" or month == "friday" or month == "saturday" :
                print("Month selected :{}".format(month.title()))
                df = pd. read_csv(gc)
                df['Start Time'] = pd.to_datetime(df['Start Time'])
                df['Days of week'] = df['Start Time'].dt.dayofweek
                mapping = {0:'monday', 1:'tuesday', 2:'wednesday', 3:'thursday', 4:'friday', 5:'saturday', 6:'sunday'}
                df = df.applymap(lambda s: mapping.get(s) if s in mapping else s)
                df = df.loc[df['Days of week'] == month]

                return(df)

            else:
                print("{} is Invalied entry, Kindly re-enter".format(month.title()))
                month = input('\nWhich day? Sunday, Monday, Tuesday, Wednesday, Thursday, Friday or saturday?\n').lower()



    elif gtp == "none":
            df = pd.read_csv(gc)
            return(df)

def popular_stations(df):
    '''
    Question: 
        What is the most popular start station and most popular end station?
    args:
        df- takes in filtered dataframe
    returns:
        popular station
    '''

    print('Popular start station is {} \nPopular end station is {}'.format(df['Start Station'].
                                                                           mode()[0], df['End Station'].mode()[0]))
    
def trip_duration(df):
    '''
    Question: What is the total trip duration and average trip duration?
    args:
        df- takes in filtered dataframe
    returns:
        trip duration in hh:mm:ss
    
    '''
    avg = str(datetime.timedelta( df['Trip Duration'].mean()))
    total = df['Trip Duration'].sum()
    print('Total trip duration {} and average trip duaration {}'.format(total, avg))
    
def popular_hour(df):
    '''
    Question: What is the most popular hour of day for start time?
    args:
        df- takes in filtered dataframe
    returns:
        popular hour
    '''
    df['Start Time'] = pd.to_datetime(df['Start Time'])
    df['hours'] = df['Start Time'].dt.hour
    df['hours'] = df['hours'] +1
    print('Popular hour is {}'.format(df['hours'].mode()[0]))

def popular_day(df):
    '''
    Question: What is the most popular day of week (Monday, Tuesday, etc.) for start time?
    args:
        df- takes in filtered dataframe
    returns:
        popular day
    '''
    df['Start Time'] = pd.to_datetime(df['Start Time'])
    df['days of week'] = df['Start Time'].dt.dayofweek
    mapping = {0:'monday', 1:'tuesday', 2:'wednesday', 3:'thursday', 4:'friday', 5:'saturday', 6:'sunday'}
    df = df.applymap(lambda s: mapping.get(s) if s in mapping else s)
    print('Popular day is {} '.format(df['days of week'].mode()[0]))
    
def popular_month(df):
    '''Returns: the month with highest no of trips
    Question: What is the most popular month for start time?
    args:
        df- takes in filtered dataframe
    returns:
        popular month
    '''
    
    df['Start Time'] = pd.to_datetime(df['Start Time'])
    df['months'] = df['Start Time'].dt.month
    mapping = {1:'january', 2:'february', 3:'march', 4:'april', 5:'may', 6:'june'}
    df = df.applymap(lambda s: mapping.get(s) if s in mapping else s)
    print('Popular month is {} '.format((df['months'].mode()[0])))
    
def popular_trip(df):
    '''
    Question: What is the most popular trip?
    args:
        df- takes in filtered dataframe
    returns
        popupar trip
    '''
    df['pop_sta'] = 'from ' +df['Start Station'].str.cat(' to ' +df['End Station'])
    df['pop_sta'].mode()[0]
    print('Popular trip is {}'.format(df['pop_sta'].mode()[0]))

def display_data(df):
    '''Displays five lines of data if the user specifies that they would like to.
    After displaying five lines, ask the user if they would like to see five more,
    continuing asking until they say stop.

    Args:
        df - filtered dataframe
    Returns:
        TODO: fill out return type and description (see get_city for an example)
    '''
    
    while True:
        displayy = input('\nWould you like to view individual trip data?'
                        'Type \'yes\' or \'no\'.\n')
        if displayy == 'no':
            break
        elif displayy == 'yes':
            
            display(df.head())
        else:
            print ('Type valid input')
        
def birth_years(df, city_name):
    '''
    Question: What are the earliest (i.e. oldest user), most recent (i.e. youngest user),
    and most popular birth years? 
    args:
        df- takes in filtered dataframe
    returns:
        popular years
    '''
    if city_name == 'washington.csv':
        return('No data on birth year')

    else:
        print('The oldest user birth year is {} \nThe youngest user birth year is {} \nThe popular birth year is {}'.
              format(int(df['Birth Year'].max()),int(df['Birth Year'].min()),int(df['Birth Year'].mode()[0])))

def gender(df,city_name):
    '''
    Question: What are the counts of gender?
    args:
        df- takes in filtered dataframe
    returns:
        gender that is popular
    '''
    if city_name == 'washington.csv':
        return('No data on gender')

    else:
        counts = df['Gender'].value_counts().to_dict()
        print ('The count of gender is {}'.format(counts))

def users(df):
    '''
    Question: What are the counts of each user type?
    args:
        df- takes in filtered dataframe
    '''
    counts = df['User Type'].value_counts().to_dict()
    print ('The count of each user type is {}'.format(counts))

def statistics():
    '''
    using the functions returns the statistics for the filtered data according to the input
    '''
    gc = get_city()
    gtt = get_time_period()
    df_filtered = get_names(gtt,gc)

    start_time = time.time()
    print('\n')
    popular_month(df_filtered)
    print("That took %s seconds.\n\n" % (time.time() - start_time))
    
    print("Calculating the next statistic...")
    start_time = time.time()
    popular_day(df_filtered)
    print("That took %s seconds.\n\n" % (time.time() - start_time))

    print("Calculating the next statistic...")
    start_time = time.time()
    gender(df_filtered, gc)
    print("That took %s seconds.\n\n" % (time.time() - start_time))

    print("Calculating the next statistic...")
    start_time = time.time()
    birth_years(df_filtered, gc)
    print("That took %s seconds.\n\n" % (time.time() - start_time))

    print("Calculating the next statistic...")
    start_time = time.time()
    users(df_filtered)
    print("That took %s seconds.\n\n" % (time.time() - start_time))\

    print("Calculating the next statistic...")
    start_time = time.time()
    popular_trip(df_filtered)
    print("That took %s seconds.\n\n" % (time.time() - start_time))

    print("Calculating the next statistic...")
    start_time = time.time()
    popular_stations(df_filtered)
    print("That took %s seconds.\n\n" % (time.time() - start_time))

    print("Calculating the next statistic...")
    start_time = time.time()
    trip_duration(df_filtered)
    print("That took %s seconds.\n\n" % (time.time() - start_time))

    print("Calculating the next statistic...")
    start_time = time.time()
    popular_hour(df_filtered)
    print("That took %s seconds.\n\n" % (time.time() - start_time))

        # Restart?
    restart = input('\nWould you like to restart? Type \'yes\' or \'no\'.\n')
    if restart.lower() == 'yes':
        statistics()
        
    display_data(df_filtered)

# %%
statistics()
# Out:
# Hello! Let's explore some US bikeshare data!
# Would you like to see data for Chicago, New York, or Washington?
# chicago
#
# Would you like to filter the data by month, day, or none at all? Type "none" for no time filter.
# month
# Time Period selected :month
#
# Which month? January, February, March, April, May, or June?
# april
# Month selected :April
#
#
# Popular month is april
# That took 2.7773537635803223 seconds.
#
#
# Calculating the next statistic...
# Popular day is saturday
# That took 2.7583351135253906 seconds.
#
#
# Calculating the next statistic...
# The count of gender is {'Male': 157398, 'Female': 50070}
# That took 0.03712177276611328 seconds.
#
#
# Calculating the next statistic...
# The oldest user birth year is 2016
# The youngest user birth year is 1899
# The popular birth year is 1989
# That took 0.033065080642700195 seconds.
#
#
# Calculating the next statistic...
# The count of each user type is {'Subscriber': 207407, 'Customer': 61255}
# That took 0.05514669418334961 seconds.
#
#
# Calculating the next statistic...
# Popular trip is from Lake Shore Dr & Monroe St to Streeter Dr & Grand Ave
# That took 0.2825047969818115 seconds.
#
#
# Calculating the next statistic...
# Popular start station is Streeter Dr & Grand Ave
# Popular end station is Streeter Dr & Grand Ave
# That took 0.06716012954711914 seconds.
#
#
# Calculating the next statistic...
# Total trip duration 264187608 and average trip duaration 983 days, 8:17:43.831878
# That took 0.0009670257568359375 seconds.
#
#
# Calculating the next statistic...
# Popular hour is 18
# That took 0.026100873947143555 seconds.
#
#
#
# Would you like to restart? Type 'yes' or 'no'.
# no
#
# Would you like to view individual trip data?Type 'yes' or 'no'.
# yes
#                 Start Time             End Time  Trip Duration  \
# 431691 2017-04-01 00:01:35  2017-04-01 00:14:30            775
# 431692 2017-04-01 00:03:08  2017-04-01 00:08:24            316
# 431693 2017-04-01 00:04:13  2017-04-01 00:19:20            907
# 431694 2017-04-01 00:06:00  2017-04-01 00:20:53            893
# 431695 2017-04-01 00:06:30  2017-04-01 00:11:56            326
#
#                      Start Station                    End Station   User Type  \
# 431691      Michigan Ave & Lake St    Michigan Ave & Jackson Blvd  Subscriber
# 431692  Halsted St & Diversey Pkwy       Racine Ave & Belmont Ave  Subscriber
# 431693   Desplaines St & Kinzie St         Damen Ave & Pierce Ave  Subscriber
# 431694      Wabash Ave & Grand Ave         Clinton St & Tilden St  Subscriber
# 431695      Broadway & Belmont Ave  Pine Grove Ave & Waveland Ave  Subscriber
#
#        Gender  Birth Year  months  days of week  \
# 431691   Male      1987.0       4             5
# 431692   Male      1986.0       4             5
# 431693   Male      1993.0       4             5
# 431694   Male      1979.0       4             5
# 431695   Male      1960.0       4             5
#
#                                                   pop_sta  hours
# 431691  from Michigan Ave & Lake St to Michigan Ave & ...      1
# 431692  from Halsted St & Diversey Pkwy to Racine Ave ...      1
# 431693  from Desplaines St & Kinzie St to Damen Ave & ...      1
# 431694  from Wabash Ave & Grand Ave to Clinton St & Ti...      1
# 431695  from Broadway & Belmont Ave to Pine Grove Ave ...      1
# Would you like to view individual trip data?Type 'yes' or 'no'.
# yes
#                 Start Time             End Time  Trip Duration  \
# 431691 2017-04-01 00:01:35  2017-04-01 00:14:30            775
# 431692 2017-04-01 00:03:08  2017-04-01 00:08:24            316
# 431693 2017-04-01 00:04:13  2017-04-01 00:19:20            907
# 431694 2017-04-01 00:06:00  2017-04-01 00:20:53            893
# 431695 2017-04-01 00:06:30  2017-04-01 00:11:56            326
#
#                      Start Station                    End Station   User Type  \
# 431691      Michigan Ave & Lake St    Michigan Ave & Jackson Blvd  Subscriber
# 431692  Halsted St & Diversey Pkwy       Racine Ave & Belmont Ave  Subscriber
# 431693   Desplaines St & Kinzie St         Damen Ave & Pierce Ave  Subscriber
# 431694      Wabash Ave & Grand Ave         Clinton St & Tilden St  Subscriber
# 431695      Broadway & Belmont Ave  Pine Grove Ave & Waveland Ave  Subscriber
#
#        Gender  Birth Year  months  days of week  \
# 431691   Male      1987.0       4             5
# 431692   Male      1986.0       4             5
# 431693   Male      1993.0       4             5
# 431694   Male      1979.0       4             5
# 431695   Male      1960.0       4             5
#
#                                                   pop_sta  hours
# 431691  from Michigan Ave & Lake St to Michigan Ave & ...      1
# 431692  from Halsted St & Diversey Pkwy to Racine Ave ...      1
# 431693  from Desplaines St & Kinzie St to Damen Ave & ...      1
# 431694  from Wabash Ave & Grand Ave to Clinton St & Ti...      1
# 431695  from Broadway & Belmont Ave to Pine Grove Ave ...      1
# Would you like to view individual trip data?Type 'yes' or 'no'.
# no
